# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#load the data
uni = pd.read_csv('cwurData.csv')

# %%
uni.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# 0             1          1          1           NaN        5  100.00  2012
# 1            12          4          4           NaN        1   91.67  2012
# 2             4          2          2           NaN       15   89.50  2012
# 3            16         16         11           NaN       50   86.17  2012
# 4            37         22         22           NaN       18   85.21  2012

# %%
#look at the information regarding its columns
uni.info
# Out:
# <bound method DataFrame.info of       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# 0                 1                     7                  9
# 1                 2                     9                 17
# 2                 3                    17                 11
# 3                 1                    10                 24
# 4                 4                     2                 29
# ...             ...                   ...                ...
# 2195              7                   367                567
# 2196              4                   236                566
# 2197             18                   367                549
# 2198             40                   367                567
# 2199             83                   367                567
#
#       quality_of_faculty  publications  influence  citations  broad_impact  \
# 0                      1             1          1          1           NaN
# 1                      3            12          4          4           NaN
# 2                      5             4          2          2           NaN
# 3                      4            16         16         11           NaN
# 4                      7            37         22         22           NaN
# ...                  ...           ...        ...        ...           ...
# 2195                 218           926        845        812         969.0
# 2196                 218           997        908        645         981.0
# 2197                 218           830        823        812         975.0
# 2198                 218           886        974        812         975.0
# 2199                 218           861        991        812         981.0
#
#       patents   score  year
# 0           5  100.00  2012
# 1           1   91.67  2012
# 2          15   89.50  2012
# 3          50   86.17  2012
# 4          18   85.21  2012
# ...       ...     ...   ...
# 2195      816   44.03  2015
# 2196      871   44.03  2015
# 2197      824   44.03  2015
# 2198      651   44.02  2015
# 2199      547   44.02  2015
#
# [2200 rows x 14 columns]>

# %%
#checking for the null values and its counts
uni.isnull().sum()
# Out:
# world_rank                0
# institution               0
# country                   0
# national_rank             0
# quality_of_education      0
# alumni_employment         0
# quality_of_faculty        0
# publications              0
# influence                 0
# citations                 0
# broad_impact            200
# patents                   0
# score                     0
# year                      0
# dtype: int64

# %%
uni['broad_impact'].dtypes
# Out:
# dtype('float64')

# %%
#checking the broad_impact column with its null values
uni[uni['broad_impact'].notnull()].head()
# Out:
#      world_rank                            institution         country  \
# 200           1                     Harvard University             USA
# 201           2                    Stanford University             USA
# 202           3  Massachusetts Institute of Technology             USA
# 203           4                University of Cambridge  United Kingdom
# 204           5                   University of Oxford  United Kingdom
#
#      national_rank  quality_of_education  alumni_employment  \
# 200              1                     1                  1
# 201              2                    11                  2
# 202              3                     3                 11
# 203              1                     2                 10
# 204              2                     7                 12
#
#      quality_of_faculty  publications  influence  citations  broad_impact  \
# 200                   1             1          1          1           1.0
# 201                   4             5          3          3           4.0
# 202                   2            15          2          2           2.0
# 203                   5            10          9         12          13.0
# 204                  10            11         12         11          12.0
#
#      patents   score  year
# 200        2  100.00  2014
# 201        6   99.09  2014
# 202        1   98.69  2014
# 203       48   97.64  2014
# 204       16   97.51  2014

# %%
uni.sort_values('broad_impact', ascending=False)
# Out:
#       world_rank                                 institution       country  \
# 1199        1000                          Yanbian University         China
# 1449         250  Moscow Institute of Physics and Technology        Russia
# 2174         975                         Shenzhen University         China
# 1198         999   National University of Defense Technology         China
# 1191         992                   King Abdulaziz University  Saudi Arabia
# ...          ...                                         ...           ...
# 195           96              Australian National University     Australia
# 196           97                       University of Alberta        Canada
# 197           98                      University of Helsinki       Finland
# 198           99          Paris Diderot University - Paris 7        France
# 199          100             Georgia Institute of Technology           USA
#
#       national_rank  quality_of_education  alumni_employment  \
# 1199             84                   355                478
# 1449              2                    23                339
# 2174             75                   367                410
# 1198             83                   355                478
# 1191              4                   355                470
# ...             ...                   ...                ...
# 195               2                   101                101
# 196               4                   101                101
# 197               1                    69                101
# 198               5                    28                101
# 199              57                   101                 85
#
#       quality_of_faculty  publications  influence  citations  broad_impact  \
# 1199                 210           890        790        800        1000.0
# 1449                 218           949        605        812        1000.0
# 2174                 218           976        778        645         999.0
# 1198                 210           860        973        800         999.0
# 1191                 210           843        688        609         998.0
# ...                  ...           ...        ...        ...           ...
# 195                   43           101        101        101           NaN
# 196                  101            68        101         92           NaN
# 197                   81            74         79         71           NaN
# 198                   72           101         87        101           NaN
# 199                  101            97        101         43           NaN
#
#       patents  score  year
# 1199      737  44.18  2014
# 1449      839  46.55  2015
# 2174      318  44.05  2015
# 1198      637  44.21  2014
# 1191      637  44.26  2014
# ...       ...    ...   ...
# 195       101  44.50  2013
# 196        81  44.50  2013
# 197       101  44.39  2013
# 198       101  44.36  2013
# 199        32  44.26  2013
#
# [2200 rows x 14 columns]

# %% [markdown]
# Broader Impacts refers to the potential for a research project to benefit society or advance desired societal outcomes. Those outcomes include, but are not limited to: full participation of women, persons with disabilities, and underrepresented minorities; ... enhanced infrastructure for research and education.
#
# source:https://research.fas.harvard.edu/broader-impacts#:~:text=Broader%20Impacts%20refers%20to%20the,with%20disabilities%2C%20and%20underrepresented%20minorities%3B&text=enhanced%20infrastructure%20for%20research%20and%20education.

# %%
#we can conclude that the 200 null values in broad_impact columns were a result of repetitive column
#we can drop the null values rows, drops rows where any row has a missing value - this does not happen *in place*, so we are not actually dropping
uni['broad_impact'].dropna()
# Out:
# 200       1.0
# 201       4.0
# 202       2.0
# 203      13.0
# 204      12.0
#         ...
# 2195    969.0
# 2196    981.0
# 2197    975.0
# 2198    975.0
# 2199    981.0
# Name: broad_impact, Length: 2000, dtype: float64

# %%
# drops all nulls from the broad_impact column, but returns the entire dataframe instead of just the broad_impact column
uni.dropna(subset=['broad_impact'], inplace =True)

# %%
#it also cleared the data from early years(2012, 2013) making the data a bit more updated
uni.head()
# Out:
#      world_rank                            institution         country  \
# 200           1                     Harvard University             USA
# 201           2                    Stanford University             USA
# 202           3  Massachusetts Institute of Technology             USA
# 203           4                University of Cambridge  United Kingdom
# 204           5                   University of Oxford  United Kingdom
#
#      national_rank  quality_of_education  alumni_employment  \
# 200              1                     1                  1
# 201              2                    11                  2
# 202              3                     3                 11
# 203              1                     2                 10
# 204              2                     7                 12
#
#      quality_of_faculty  publications  influence  citations  broad_impact  \
# 200                   1             1          1          1           1.0
# 201                   4             5          3          3           4.0
# 202                   2            15          2          2           2.0
# 203                   5            10          9         12          13.0
# 204                  10            11         12         11          12.0
#
#      patents   score  year
# 200        2  100.00  2014
# 201        6   99.09  2014
# 202        1   98.69  2014
# 203       48   97.64  2014
# 204       16   97.51  2014

# %%
#checking for any null values after dropping rows
uni['broad_impact'].isnull().sum()
# Out:
# 0

# %%
#checking the real number of universities in this ranking
uni[['institution','world_rank']].groupby('institution').max().sort_values('world_rank',ascending=True)
# Out:
#                                            world_rank
# institution
# Harvard University                                  1
# Stanford University                                 2
# Massachusetts Institute of Technology               3
# University of Cambridge                             4
# University of Oxford                                5
# ...                                               ...
# Federal University of Ceará                       998
# University of A Coruña                            999
# National University of Defense Technology         999
# Yanbian University                               1000
# China Pharmaceutical University                  1000
#
# [1023 rows x 1 columns]

# %%
uni['year'].nunique()
# Out:
# 2

# %%
uni['year'].value_counts(dropna=False)
#there are two datas of a single insitution based on year 2014 and 2015
#23 universities drop from the top 1000 ranking in 2015 from 2014
# Out:
# 2014    1000
# 2015    1000
# Name: year, dtype: int64

# %%
#dropping the year that is not the latest year of data
uniyear = uni[~(uni['year'] == 2015)].index 
uni.drop(uniyear , inplace=True)

# %%
uni.head()
# Out:
#       world_rank                            institution         country  \
# 1200           1                     Harvard University             USA
# 1201           2                    Stanford University             USA
# 1202           3  Massachusetts Institute of Technology             USA
# 1203           4                University of Cambridge  United Kingdom
# 1204           5                   University of Oxford  United Kingdom
#
#       national_rank  quality_of_education  alumni_employment  \
# 1200              1                     1                  1
# 1201              2                     9                  2
# 1202              3                     3                 11
# 1203              1                     2                 10
# 1204              2                     7                 13
#
#       quality_of_faculty  publications  influence  citations  broad_impact  \
# 1200                   1             1          1          1           1.0
# 1201                   4             5          3          3           4.0
# 1202                   2            15          2          2           2.0
# 1203                   5            11          6         12          13.0
# 1204                  10             7         12          7           9.0
#
#       patents   score  year
# 1200        3  100.00  2015
# 1201       10   98.66  2015
# 1202        1   97.54  2015
# 1203       48   96.81  2015
# 1204       15   96.46  2015

# %%
uni.tail()
# Out:
#       world_rank                      institution   country  national_rank  \
# 2195         996        University of the Algarve  Portugal              7
# 2196         997            Alexandria University     Egypt              4
# 2197         998      Federal University of Ceará    Brazil             18
# 2198         999           University of A Coruña     Spain             40
# 2199        1000  China Pharmaceutical University     China             83
#
#       quality_of_education  alumni_employment  quality_of_faculty  \
# 2195                   367                567                 218
# 2196                   236                566                 218
# 2197                   367                549                 218
# 2198                   367                567                 218
# 2199                   367                567                 218
#
#       publications  influence  citations  broad_impact  patents  score  year
# 2195           926        845        812         969.0      816  44.03  2015
# 2196           997        908        645         981.0      871  44.03  2015
# 2197           830        823        812         975.0      824  44.03  2015
# 2198           886        974        812         975.0      651  44.02  2015
# 2199           861        991        812         981.0      547  44.02  2015

# %%
#confirming the final amount of datas
uni.count()
# Out:
# world_rank              1000
# institution             1000
# country                 1000
# national_rank           1000
# quality_of_education    1000
# alumni_employment       1000
# quality_of_faculty      1000
# publications            1000
# influence               1000
# citations               1000
# broad_impact            1000
# patents                 1000
# score                   1000
# year                    1000
# dtype: int64

# %%
uni.head()
# Out:
#       world_rank                            institution         country  \
# 1200           1                     Harvard University             USA
# 1201           2                    Stanford University             USA
# 1202           3  Massachusetts Institute of Technology             USA
# 1203           4                University of Cambridge  United Kingdom
# 1204           5                   University of Oxford  United Kingdom
#
#       national_rank  quality_of_education  alumni_employment  \
# 1200              1                     1                  1
# 1201              2                     9                  2
# 1202              3                     3                 11
# 1203              1                     2                 10
# 1204              2                     7                 13
#
#       quality_of_faculty  publications  influence  citations  broad_impact  \
# 1200                   1             1          1          1           1.0
# 1201                   4             5          3          3           4.0
# 1202                   2            15          2          2           2.0
# 1203                   5            11          6         12          13.0
# 1204                  10             7         12          7           9.0
#
#       patents   score  year
# 1200        3  100.00  2015
# 1201       10   98.66  2015
# 1202        1   97.54  2015
# 1203       48   96.81  2015
# 1204       15   96.46  2015

# %%
#resetting the index
uni = uni.reset_index(drop=True)

# %%
uni.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2                    Stanford University             USA
# 2           3  Massachusetts Institute of Technology             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5                   University of Oxford  United Kingdom
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     1                  1                   1
# 1              2                     9                  2                   4
# 2              3                     3                 11                   2
# 3              1                     2                 10                   5
# 4              2                     7                 13                  10
#
#    publications  influence  citations  broad_impact  patents   score  year
# 0             1          1          1           1.0        3  100.00  2015
# 1             5          3          3           4.0       10   98.66  2015
# 2            15          2          2           2.0        1   97.54  2015
# 3            11          6         12          13.0       48   96.81  2015
# 4             7         12          7           9.0       15   96.46  2015

# %%
uni.tail()
# Out:
#      world_rank                      institution   country  national_rank  \
# 995         996        University of the Algarve  Portugal              7
# 996         997            Alexandria University     Egypt              4
# 997         998      Federal University of Ceará    Brazil             18
# 998         999           University of A Coruña     Spain             40
# 999        1000  China Pharmaceutical University     China             83
#
#      quality_of_education  alumni_employment  quality_of_faculty  \
# 995                   367                567                 218
# 996                   236                566                 218
# 997                   367                549                 218
# 998                   367                567                 218
# 999                   367                567                 218
#
#      publications  influence  citations  broad_impact  patents  score  year
# 995           926        845        812         969.0      816  44.03  2015
# 996           997        908        645         981.0      871  44.03  2015
# 997           830        823        812         975.0      824  44.03  2015
# 998           886        974        812         975.0      651  44.02  2015
# 999           861        991        812         981.0      547  44.02  2015

# %% [markdown]
# DATA CLEANING COMPLETED......

# %%
#checking the number of unique country holding the top 1000 institute
country_counts = uni["country"].value_counts()
print(country_counts)
# Out:
# USA                     229
# China                    83
# Japan                    74
# United Kingdom           65
# Germany                  55
# France                   49
# Italy                    47
# Spain                    40
# South Korea              36
# Canada                   33
# Australia                27
# Taiwan                   21
# Brazil                   18
# India                    16
# Netherlands              13
# Austria                  12
# Sweden                   11
# Belgium                  10
# Turkey                   10
# Poland                    9
# Finland                   9
# Switzerland               9
# Iran                      8
# Ireland                   8
# Portugal                  7
# Greece                    7
# Israel                    7
# Hong Kong                 6
# Hungary                   6
# New Zealand               6
# Russia                    5
# Denmark                   5
# Czech Republic            5
# South Africa              5
# Norway                    5
# Egypt                     4
# Saudi Arabia              4
# Chile                     4
# Malaysia                  3
# Thailand                  3
# Argentina                 3
# Slovenia                  2
# Romania                   2
# Colombia                  2
# Singapore                 2
# Mexico                    2
# Puerto Rico               1
# Cyprus                    1
# Uganda                    1
# Lebanon                   1
# Slovak Republic           1
# Iceland                   1
# Bulgaria                  1
# United Arab Emirates      1
# Lithuania                 1
# Estonia                   1
# Croatia                   1
# Serbia                    1
# Uruguay                   1
# Name: country, dtype: int64

# %%
#for styling purpose
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %%
#countries holding the most numbers of top 1000 institution
uni['country'].value_counts().head().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
uni.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2                    Stanford University             USA
# 2           3  Massachusetts Institute of Technology             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5                   University of Oxford  United Kingdom
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     1                  1                   1
# 1              2                     9                  2                   4
# 2              3                     3                 11                   2
# 3              1                     2                 10                   5
# 4              2                     7                 13                  10
#
#    publications  influence  citations  broad_impact  patents   score  year
# 0             1          1          1           1.0        3  100.00  2015
# 1             5          3          3           4.0       10   98.66  2015
# 2            15          2          2           2.0        1   97.54  2015
# 3            11          6         12          13.0       48   96.81  2015
# 4             7         12          7           9.0       15   96.46  2015

# %%
uni[['world_rank', 'institution','alumni_employment']]
# Out:
#      world_rank                            institution  alumni_employment
# 0             1                     Harvard University                  1
# 1             2                    Stanford University                  2
# 2             3  Massachusetts Institute of Technology                 11
# 3             4                University of Cambridge                 10
# 4             5                   University of Oxford                 13
# ..          ...                                    ...                ...
# 995         996              University of the Algarve                567
# 996         997                  Alexandria University                566
# 997         998            Federal University of Ceará                549
# 998         999                 University of A Coruña                567
# 999        1000        China Pharmaceutical University                567
#
# [1000 rows x 3 columns]

# %%
plot1 = uni.plot(kind='scatter', x='world_rank', y='alumni_employment', \
        color='dodgerblue', figsize=(10,4), s=10, alpha=0.5)

# %%
#inverse the plot axis because the ranking is greater when the number is smaller
plot2 = uni.plot(kind='scatter', x='world_rank', y='alumni_employment', \
        color='dodgerblue', figsize=(10,4), s=10, alpha=0.5)
plot2.set_title("Inverted Plot")
plot2.invert_xaxis()
plot2.invert_yaxis()

# %% [markdown]
# Data Visualisation Completed....

# %%
#create app
uni.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2                    Stanford University             USA
# 2           3  Massachusetts Institute of Technology             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5                   University of Oxford  United Kingdom
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     1                  1                   1
# 1              2                     9                  2                   4
# 2              3                     3                 11                   2
# 3              1                     2                 10                   5
# 4              2                     7                 13                  10
#
#    publications  influence  citations  broad_impact  patents   score  year
# 0             1          1          1           1.0        3  100.00  2015
# 1             5          3          3           4.0       10   98.66  2015
# 2            15          2          2           2.0        1   97.54  2015
# 3            11          6         12          13.0       48   96.81  2015
# 4             7         12          7           9.0       15   96.46  2015

# %%
uni.shape
# Out:
# (1000, 14)

# %%
len(uni)
# Out:
# 1000

# %%
type(uni)
# Out:
# pandas.core.frame.DataFrame

# %%
#convert data frame into dictionary
uni_dict=uni.to_dict()

# %%
type(uni_dict)
# Out:
# dict

# %%
uni_dict['alumni_employment']
# Out:
# {0: 1,
#  1: 2,
#  2: 11,
#  3: 10,
#  4: 13,
#  5: 6,
#  6: 21,
#  7: 14,
#  8: 15,
#  9: 18,
#  10: 26,
#  11: 328,
#  12: 3,
#  13: 4,
#  14: 27,
#  15: 84,
#  16: 16,
#  17: 22,
#  18: 17,
#  19: 64,
#  20: 567,
#  21: 12,
#  22: 164,
#  23: 9,
#  24: 29,
#  25: 567,
#  26: 447,
#  27: 31,
#  28: 567,
#  29: 36,
#  30: 103,
#  31: 51,
#  32: 75,
#  33: 5,
#  34: 82,
#  35: 7,
#  36: 502,
#  37: 8,
#  38: 567,
#  39: 69,
#  40: 20,
#  41: 37,
#  42: 33,
#  43: 19,
#  44: 39,
#  45: 169,
#  46: 44,
#  47: 130,
#  48: 87,
#  49: 40,
#  50: 62,
#  51: 96,
#  52: 227,
#  53: 67,
#  54: 127,
#  55: 38,
#  56: 25,
#  57: 393,
#  58: 175,
#  59: 276,
#  60: 160,
#  61: 275,
#  62: 404,
#  63: 280,
#  64: 98,
#  65: 54,
#  66: 92,
#  67: 55,
#  68: 94,
#  69: 105,
#  70: 567,
#  71: 210,
#  72: 170,
#  863: 456,
#  864: 567,
#  865: 567,
#  866: 567,
#  867: 567,
#  868: 567,
#  869: 354,
#  870: 315,
#  871: 567,
#  872: 561,
#  873: 567,
#  874: 320,
#  875: 567,
#  876: 567,
#  877: 567,
#  878: 524,
#  879: 567,
#  880: 255,
#  881: 567,
#  882: 302,
#  883: 528,
#  884: 458,
#  885: 567,
#  886: 567,
#  887: 463,
#  888: 567,
#  889: 567,
#  890: 346,
#  891: 567,
#  892: 374,
#  893: 567,
#  894: 486,
#  895: 567,
#  896: 567,
#  897: 567,
#  898: 567,
#  899: 567,
#  900: 567,
#  901: 518,
#  902: 567,
#  903: 558,
#  904: 567,
#  905: 567,
#  906: 298,
#  907: 567,
#  908: 349,
#  909: 509,
#  910: 567,
#  911: 567,
#  912: 567,
#  913: 567,
#  914: 313,
#  915: 567,
#  916: 567,
#  917: 567,
#  918: 567,
#  919: 367,
#  920: 567,
#  921: 567,
#  922: 515,
#  923: 452,
#  924: 567,
#  925: 325,
#  926: 567,
#  927: 567,
#  928: 442,
#  929: 567,
#  930: 567,
#  931: 478,
#  932: 567,
#  933: 497,
#  934: 567,
#  935: 567,
#  936: 474,
#  937: 494,
#  938: 552,
#  939: 567,
#  940: 567,
#  941: 567,
#  942: 567,
#  943: 409,
#  944: 505,
#  945: 413,
#  946: 556,
#  947: 351,
#  948: 384,
#  949: 521,
#  950: 567,
#  951: 567,
#  952: 567,
#  953: 567,
#  954: 336,
#  955: 567,
#  956: 567,
#  957: 567,
#  958: 567,
#  959: 567,
#  960: 567,
#  961: 567,
#  962: 567,
#  963: 567,
#  964: 567,
#  965: 567,
#  966: 567,
#  967: 312,
#  968: 567,
#  969: 567,
#  970: 446,
#  971: 567,
#  972: 567,
#  973: 396,
#  974: 410,
#  975: 567,
#  976: 567,
#  977: 567,
#  978: 567,
#  979: 567,
#  980: 529,
#  981: 567,
#  982: 434,
#  983: 567,
#  984: 567,
#  985: 567,
#  986: 567,
#  987: 567,
#  988: 567,
#  989: 567,
#  990: 542,
#  991: 540,
#  992: 327,
#  993: 567,
#  994: 449,
#  995: 567,
#  996: 566,
#  997: 549,
#  998: 567,
#  999: 567}

# %%
uni.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2                    Stanford University             USA
# 2           3  Massachusetts Institute of Technology             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5                   University of Oxford  United Kingdom
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     1                  1                   1
# 1              2                     9                  2                   4
# 2              3                     3                 11                   2
# 3              1                     2                 10                   5
# 4              2                     7                 13                  10
#
#    publications  influence  citations  broad_impact  patents   score  year
# 0             1          1          1           1.0        3  100.00  2015
# 1             5          3          3           4.0       10   98.66  2015
# 2            15          2          2           2.0        1   97.54  2015
# 3            11          6         12          13.0       48   96.81  2015
# 4             7         12          7           9.0       15   96.46  2015

# %%
#create an app class
class uni_choice:
    
    def __init__(self, country, national_rank):
        self.country = country
        self.rank = national_rank
        
    def suggestion(self):
        self.un1 = uni.loc[['country']==self.country, ['national_rank']==self.rank]

# %%
suggest1 = uni_choice("USA", 1)

# %%
suggest1.suggestion
# Out:
# <bound method uni_choice.suggestion of <__main__.uni_choice object at 0x0000020156AD2220>>

# %%
uni.loc[0]
# Out:
# world_rank                               1
# institution             Harvard University
# country                                USA
# national_rank                            1
# quality_of_education                     1
# alumni_employment                        1
# quality_of_faculty                       1
# publications                             1
# influence                                1
# citations                                1
# broad_impact                           1.0
# patents                                  3
# score                                100.0
# year                                  2015
# Name: 0, dtype: object

# %%
#suggest uni
suggested_uni = uni.loc[(uni['country'] == "USA") & (uni["national_rank"] == 1), "institution"].item()

# %%
print(suggested_uni)
# Out:
# Harvard University

# %%
#class for university suggestion
class uni_choice(object):
    def __init__(self, country, rank=1):
        self.country = country
        self.rank = rank
        
    def suggest(self):
        return uni.loc[(uni['country'] == self.country) & (uni["national_rank"] == self.rank), "institution"].item()
        
    
        

test1 = uni_choice("USA")
#need bracket at then end otherwise it will print the bound method.[BUG]
test1.suggest()
# Out:
# 'Harvard University'

# %%
#check university ranking
class uni_ranking(object):
    def __init__(self, keywords):
        self.keywords = keywords
        
    def ranking(self):
        rnk = uni[[str(self.keywords), "institution"]]
        return rnk.sort_values(by=str(self.keywords))  #sort the rankings from top to lowest

test2 = uni_ranking("patents")

test2.ranking()
# Out:
#      patents                                 institution
# 2          1       Massachusetts Institute of Technology
# 15         2                    Johns Hopkins University
# 0          3                          Harvard University
# 5          4                         Columbia University
# 59         5                       University of Florida
# ..       ...                                         ...
# 904      871                      University of Thessaly
# 328      871         Vita-Salute San Raffaele University
# 906      871                  Wilfrid Laurier University
# 754      871  National Research Nuclear University MEPhI
# 905      871                          Oakland University
#
# [1000 rows x 2 columns]

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
class uni_choice(object): #create a uni suggestion class
    def __init__(self, country, rank=1): #initialize 
        self.country = country
        self.rank = rank
        
    def suggest(self):
        return uni.loc[(uni['country'] == self.country) & (uni["national_rank"] == self.rank), "institution"].item() #locate the best university in any country
    
count1 = 0

while count1 !=1:  #while loop until a value exist in uni is given
    country = input("Check the best university that a country has to offer: ")
    tof1 = uni.isin([country]).any().any()  #checking if wether there are said country in the dataframe   
    
    if tof1 == True:
        count1 +=1
        
        if count1 ==1:
            unichoice=uni_choice(country) #call function in class uni_choice
            print(unichoice.suggest())
              
    else:
        print("This country doesn't hold any of the Global Top 1000 Universities. Try again with other countries...")
        count1 = 0 #keep the while loop going
# Out:
# Check the best university that a country has to offer: USA
# Harvard University

# %%
class uni_ranking(object): #create uni_ranking class
    def __init__(self, keyword): #initialize
        self.keyword = keyword
        
    def ranking(self):
        rnk = uni[["institution", str(self.keyword)]] #display output as institution and selected keyword
        print(rnk.sort_values(by=str(self.keyword)))  #sort the rankings from top to lowest

#to help keep the while loop goes if the user enter incorrect values
kywrd = ['world_rank', 'national_rank', 'quality_of_education', 'alumni_employment','quality_of_faculty','publications','influence', 'citations', 'broad_impact', 'patents']

count2 = 0
while count2 != 1:
    keyword = input("Enter any of the following")#user input the keywords for ranking
    if keyword in kywrd:
        count2 +=1
        if count2 == 1:
            rnks = uni_ranking(keyword)
            print(rnks.ranking())
            
    else:
        print("Put only selected values")
        count2 = 0 #reset the counter
# Out:
# Enter any of the followingpatents
#                                     institution  patents
# 2         Massachusetts Institute of Technology        1
# 15                     Johns Hopkins University        2
# 0                            Harvard University        3
# 5                           Columbia University        4
# 59                        University of Florida        5
# ..                                          ...      ...
# 904                      University of Thessaly      871
# 328         Vita-Salute San Raffaele University      871
# 906                  Wilfrid Laurier University      871
# 754  National Research Nuclear University MEPhI      871
# 905                          Oakland University      871
#
# [1000 rows x 2 columns]
# None

# %%
#final draft of university searching app

#the homepage of the app uses three inputs: ['suggest_universities, 'check_ranking, 'exit_app'
print('Hi! Welcome to the Global Top 1000 Uni App!')
print('Enter any of the following commands to access the app functions :   ')
print('suggest_university= suggestion for university choice in the selected country')
print('check_ranking = ranking of the universities in different areas')
print('exit_app = close the app')

count3 = 0 #this is the counter for while loop for the app homepage

while count3 != 1:  #while loop for the app homepage  
    #user homepage input
    intro = input ('Please enter a command :   ')
    
    if intro == "suggest_university" :
        count1 = 0 #loop for the uni_choice function
        
        while count1 !=1:  #while loop until a value exist in uni is given
            country = input("Check the best university that a country has to offer :   ")#uni_choice user input here
            tof1 = uni.isin([country]).any().any()  #checking if wether there are said country in the dataframe   
    
            if tof1 == True: #condition to safeguard faulty user input
                count1 +=1
        
                if count1 ==1: #function if True
                    unichoice=uni_choice(country) #call function in class uni_choice
                    print(unichoice.suggest()) #has parentheses to print the result out instead of the bound method
              
            else:
                print("This country doesn't hold any of the Global Top 1000 Universities. Try again with other countries...")
                count1 = 0 #keep the while loop going
                  
        count3 = 0#need checking loop
        
    elif intro == "check_ranking":
        #to help keep the while loop goes if the user enter incorrect values
        kywrd = ['world_rank', 'national_rank', 'quality_of_education', 'alumni_employment','quality_of_faculty','publications','influence', 'citations', 'broad_impact', 'patents']

        count2 = 0#counter for check_ranking function
        
        while count2 != 1: #while loop for check_ranking
            print('Ranking Options :   ')
            print(kywrd) #display options to user
            keyword = input("Enter any of the ranking preference as the following options above :   ")#uni_ranking user inputs
            
            if keyword in kywrd: #checking for the keyword from the list kywrd
                count2 +=1
                
                if count2 == 1:
                    rnks = uni_ranking(keyword) #call function in uni_ranking class
                    print(rnks.ranking())#call function of .ranking()
            
            else:
                print("Put only of the given options")
                count2 = 0 #reset the counter
        
        count3=0# need checking loop
        
    elif intro=="exit_app":  #closing the app function
        print('Exiting the app....')
        print('App closed. See you later!')
        count3 +=1
        
    else :
        print("Enter only the commands provided.")#user input error safe guard
        count3 = 0
# Out:
# Hi! Welcome to the Global Top 1000 Uni App!
# Enter any of the following commands to access the app functions :
# suggest_university= suggestion for university choice in the selected country
# check_ranking = ranking of the universities in different areas
# exit_app = close the app
# Please enter a command :   check_ranking
# Ranking Options :
# ['world_rank', 'national_rank', 'quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations', 'broad_impact', 'patents']
# Enter any of the ranking preference as the following options above :   world_rank
#                                institution  world_rank
# 0                       Harvard University           1
# 1                      Stanford University           2
# 2    Massachusetts Institute of Technology           3
# 3                  University of Cambridge           4
# 4                     University of Oxford           5
# ..                                     ...         ...
# 995              University of the Algarve         996
# 996                  Alexandria University         997
# 997            Federal University of Ceará         998
# 998                 University of A Coruña         999
# 999        China Pharmaceutical University        1000
#
# [1000 rows x 2 columns]
# None
# Please enter a command :   exit_app
# Exiting the app....
# App closed. See you later!

# %% [markdown]
# Questions to asked:
# 1. check_ranking output display
# 2. data visualisation included in app?
